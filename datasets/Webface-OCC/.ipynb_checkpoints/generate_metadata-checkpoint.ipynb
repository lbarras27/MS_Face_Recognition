# %%
import os, sys
import numpy as np
import pandas as pd
import dataset

# %%
occlusions = ["original", "glass", "surgical"]

# generate metadata for verification
identities_imgs_name = dataset.get_identities_imgs_name("imgs")
for occ in occlusions[1:]:
    res, res2 = dataset.generate_pairs_mixed(identities_imgs_name, "original", occ)
    dataset.write_pairs(res, res2, "metadata/original_{}_pairs_list.txt".format(occ))

identities_imgs_name = dataset.get_original_identities_imgs_name("imgs")
res, res2 = dataset.generate_pairs(identities_imgs_name)
dataset.write_pairs(res, res2, "metadata/original_original_pairs_list.txt")

# generate metadata for identification
dataset.generate_file_with_all_identities_names("imgs", "metadata/all_img_names.txt")
for occ in occlusions:
    dataset.generate_probe_gallery_set("metadata/all_img_names.txt", "metadata/gallery_set_original_{}.txt".format(occ),
                                       "metadata/prob_set_{}.txt".format(occ), "original", occ)
# Out:
# metadata/all_img_names.txt generated
# 45
# 106
# 150
# 205
# 321
# 390
# 420
# 429
# 501
# 503
# 640
# 650
# 701
# 722
# 769
# 791
# 802
# 804
# 827
# 861
# 865
# 928
# 972
# 993
# 1021
# 1037
# 1075
# 1091
# 1141
# 1148
# 1165
# 1208
# 1232
# 1239
# 1267
# 1274
# 1279
# 1281
# 1291
# 1319
# 1334
# 1353
# 1359
# 1392
# 1401
# 1447
# 1463
# 1527
# 1616
# 1624
# 1653
# 1659
# 1681
# 1698
# 1713
# 1716
# 1733
# 1736
# 1737
# 1742
# 1773
# 1821
# 1842
# 1871
# 1878
# 1923
# 1962
# 2016
# 2025
# 2048
# 2053
# 2066
# 2071
# 2089
# 2091
# 2098
# 2161
# 2193
# 2197
# 2237
# 2259
# 2277
# 2295
# 2298
# 2339
# 2375
# 2443
# 2456
# 2457
# 2466
# 2587
# 2630
# 2642
# 2665
# 2718
# 2759
# 2788
# 2838
# 2945
# 2955
# 3005
# 3039
# 3045
# 3071
# 3136
# 3140
# 3141
# 3173
# 3192
# 3193
# 3202
# 3207
# 3228
# 3234
# 3264
# 3294
# 3319
# 3329
# 3382
# 3390
# 3401
# 3411
# 3428
# 3435
# 3446
# 3462
# 3476
# 3502
# 3528
# 3579
# 3616
# 3627
# 3644
# 3665
# 3695
# 3714
# 3736
# 3769
# 3773
# 3830
# ...
