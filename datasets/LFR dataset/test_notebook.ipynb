# %%
import dataset
import numpy as np
import pandas as pd
import os, sys

# %%
identities_img_names = dataset.get_identities_imgs_name(path="LFR dataset", dir=None)
identities_img_names

# %%
res, res2 = dataset.generate_pairs(identities_img_names)

# %%
dataset.write_pairs(res, res2, "lfr_mixed_pairs_list.txt")

# %%
identities_img_names = dataset.get_identities_imgs_name(path="LFR dataset", dir="left")
res, res2 = dataset.generate_pairs(identities_img_names)
dataset.write_pairs(res, res2, "lfr_left_pairs_list.txt")

# %%
identities_img_names = dataset.get_identities_imgs_name(path="LFR dataset", dir="right")
res, res2 = dataset.generate_pairs(identities_img_names)
dataset.write_pairs(res, res2, "lfr_right_pairs_list.txt")

# %%
identities_img_names = dataset.get_identities_imgs_name(path="LFR dataset", dir="front")
res, res2 = dataset.generate_pairs(identities_img_names)
dataset.write_pairs(res, res2, "lfr_front_pairs_list.txt")

# %%
identities_img_names = dataset.get_identities_imgs_name(path="LFR dataset", dir=None)
res, res2 = dataset.generate_pairs_mixed(identities_img_names, "front", "left")
dataset.write_pairs(res, res2, "lfr_front_left_pairs_list.txt")

# %%
res, res2 = dataset.generate_pairs_mixed(identities_img_names, "left", "right")
dataset.write_pairs(res, res2, "lfr_left_right_pairs_list.txt")

# %%
res, res2 = dataset.generate_pairs_mixed(identities_img_names, "front", "right")
dataset.write_pairs(res, res2, "lfr_front_right_pairs_list.txt")

# %%
dataset.generate_file_with_all_img_names_ids("LFR dataset", "all_img_names.txt")

# %%
dataset.generate_probe_gallery_set("all_img_names.txt", "gallery_set_front2.txt", "probe_set_right.txt", "front", "right")
# Out:
# 5
# 10
# 11
# 28
# 46
# 67
# 72
# 78
# 108
# 120
# 138
# 146
# 147
# 151
# 172
# gallery:173
# 180
# 200
# 205
# 211
# 237
# 263
# 280
# 285
# 291
# 297
# 316
# 320
# 330
# 333
# 343
# 359
# 365
# 367
# 375
# 380
# 387
# 411
# 418
# 421
# 424
# 427
# 428
# 434
# 441
# 455
# 462
# 468
# 479
# 495
# 508
# 517
# 519
# 544
# 546
# 550
# 557
# 560
# 565
# 590
# 624
# 637
# 640
# 657
# 669
# 684
# 686
# 687
# 689
# 697
# 711
# 714
# 724
# 740
# 761
# 783
# 790
# 824
# 848
# 855
# 863
# 867
# 875
# 882
# 892
# 900
# 901
# 910
# 927
# 939
# 966
# 967
# 1004
# 1026
# 1054
# 1061
# 1063
# 1064
# 1086
# 1093
# 1094
# 1105
# 1127
# 1138
# 1152
# 1158
# 1169
# 1170
# 1175
# 1182
# 1201
# 1203
# 1218
# 1227
# 1229
# 1266
# 1270
# 1279
# 1284
# 1295
# 1302
# 1307
# 1317
# 1323
# 1339
# 1344
# 1352
# 1371
# 1386
# 1389
# 1391
# 1404
# 1409
# 1411
# 1419
# 1420
# 1429
# 1436
# 1444
# 1449
# 1499
# 1519
# 1524
# 1533
# 1564
# 1591
# 1596
# 1601
# 1617
# 1618
# 1625
# 1628
# 1642
# 1647
# 1665
# 1670
# ...

# %%
"front" in "0711840/front/050 (1).jpg"
